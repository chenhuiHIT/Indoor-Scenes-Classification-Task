# %%
from __future__ import print_function 
from __future__ import division
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
from torch.optim import lr_scheduler

import matplotlib.pyplot as plt
import time
import os
import copy
print("PyTorch Version: ",torch.__version__)
print("Torchvision Version: ",torchvision.__version__)
# Out:
# PyTorch Version:  1.7.0
# Torchvision Version:  0.8.1

# %%
# Data augmentation and normalization for training
# Just normalization for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        transforms.RandomErasing()
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

data_dir = '/home/hui/data/kaggle/jincetest/indoor_scene'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=32,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Number of classes in the dataset
num_classes = 67

# Batch size for training (change depending on how much memory you have)
batch_size = 32

# Number of epochs to train for 
num_epochs = 60

# Flag for feature extracting. When False, we finetune the whole model, 
#   when True we only update the reshaped layer params
feature_extract = True

# %%
def train_model(model, dataloaders, criterion, optimizer, num_epochs=20):
    since = time.time()

    val_acc_history = []
    
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):            
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):

                    outputs = model(inputs)
                    loss = criterion(outputs, labels)

                    _, preds = torch.max(outputs, 1)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            if phase == 'val':
                val_acc_history.append(epoch_acc)

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, val_acc_history

# %%
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False

# %%
model_ft = models.resnet18(pretrained=True)
set_parameter_requires_grad(model_ft, feature_extract)
num_ftrs = model_ft.fc.in_features

# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, 67)

model_ft = model_ft.to(device)


criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 20 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
model_ft, hist = train_model(model_ft, dataloaders, criterion, optimizer_ft, num_epochs=num_epochs)
# Out:
# Epoch 0/59
# ----------
# train Loss: 3.7591 Acc: 0.1372
# val Loss: 2.8551 Acc: 0.3577
#
# Epoch 1/59
# ----------
# train Loss: 2.6568 Acc: 0.3941
# val Loss: 1.9514 Acc: 0.5288
#
# Epoch 2/59
# ----------
# train Loss: 2.0825 Acc: 0.4969
# val Loss: 1.5679 Acc: 0.5915
#
# Epoch 3/59
# ----------
# train Loss: 1.7889 Acc: 0.5510
# val Loss: 1.3948 Acc: 0.6341
#
# Epoch 4/59
# ----------
# train Loss: 1.5966 Acc: 0.5968
# val Loss: 1.2601 Acc: 0.6639
#
# Epoch 5/59
# ----------
# train Loss: 1.4521 Acc: 0.6251
# val Loss: 1.1879 Acc: 0.6796
#
# Epoch 6/59
# ----------
# train Loss: 1.3585 Acc: 0.6410
# val Loss: 1.1251 Acc: 0.6990
#
# Epoch 7/59
# ----------
# train Loss: 1.2724 Acc: 0.6604
# val Loss: 1.0809 Acc: 0.6960
#
# Epoch 8/59
# ----------
# train Loss: 1.2068 Acc: 0.6789
# val Loss: 1.0236 Acc: 0.7170
#
# Epoch 9/59
# ----------
# train Loss: 1.1380 Acc: 0.6936
# val Loss: 1.0393 Acc: 0.7199
#
# Epoch 10/59
# ----------
# train Loss: 1.0810 Acc: 0.7089
# val Loss: 1.0213 Acc: 0.7065
#
# Epoch 11/59
# ----------
# train Loss: 1.0155 Acc: 0.7279
# val Loss: 1.0082 Acc: 0.7117
#
# Epoch 12/59
# ----------
# train Loss: 1.0083 Acc: 0.7272
# val Loss: 0.9592 Acc: 0.7311
#
# Epoch 13/59
# ----------
# train Loss: 0.9449 Acc: 0.7414
# val Loss: 0.9581 Acc: 0.7311
#
# val Loss: 0.9971 Acc: 0.7304
#
# Epoch 39/59
# ----------
# train Loss: 0.4915 Acc: 0.8658
# val Loss: 0.9776 Acc: 0.7334
#
# Epoch 40/59
# ----------
# train Loss: 0.4687 Acc: 0.8750
# val Loss: 0.9766 Acc: 0.7229
#
# Epoch 41/59
# ----------
# train Loss: 0.4513 Acc: 0.8836
# val Loss: 0.9566 Acc: 0.7461
#
# Epoch 42/59
# ----------
# train Loss: 0.4393 Acc: 0.8809
# val Loss: 0.9771 Acc: 0.7379
#
# Epoch 43/59
# ----------
# train Loss: 0.4317 Acc: 0.8886
# val Loss: 0.9717 Acc: 0.7401
#
# Epoch 44/59
# ----------
# train Loss: 0.4367 Acc: 0.8826
# val Loss: 0.9511 Acc: 0.7580
#
# Epoch 45/59
# ----------
# train Loss: 0.4359 Acc: 0.8869
# val Loss: 0.9928 Acc: 0.7356
#
# Epoch 46/59
# ----------
# train Loss: 0.4185 Acc: 0.8843
# val Loss: 0.9423 Acc: 0.7498
#
# Epoch 47/59
# ----------
# train Loss: 0.4144 Acc: 0.8933
# val Loss: 1.0341 Acc: 0.7349
#
# Epoch 48/59
# ----------
# train Loss: 0.4224 Acc: 0.8895
# val Loss: 0.9958 Acc: 0.7394
#
# Epoch 49/59
# ----------
# train Loss: 0.4166 Acc: 0.8890
# val Loss: 1.0141 Acc: 0.7371
#
# Epoch 50/59
# ----------
# train Loss: 0.4355 Acc: 0.8871
# val Loss: 0.9597 Acc: 0.7416
#
# Epoch 51/59
# ----------
# train Loss: 0.3825 Acc: 0.8996
# val Loss: 1.0155 Acc: 0.7177
#
# Epoch 52/59
# ----------
# train Loss: 0.3774 Acc: 0.9002
# val Loss: 1.0183 Acc: 0.7267
#
# Epoch 53/59
# ----------
# train Loss: 0.3844 Acc: 0.8981
# val Loss: 1.0016 Acc: 0.7364
#
# Epoch 54/59
# ----------
# train Loss: 0.3928 Acc: 0.8936
# val Loss: 1.0057 Acc: 0.7296
#
# Epoch 55/59
# ----------
# train Loss: 0.3756 Acc: 0.8985
# val Loss: 1.0026 Acc: 0.7356
#
# Epoch 56/59
# ----------
# train Loss: 0.3810 Acc: 0.8981
# val Loss: 0.9946 Acc: 0.7341
#
# Epoch 57/59
# ----------
# train Loss: 0.3520 Acc: 0.9112
# val Loss: 0.9877 Acc: 0.7364
#
# Epoch 58/59
# ----------
# train Loss: 0.3897 Acc: 0.8972
# val Loss: 1.0078 Acc: 0.7423
#
# Epoch 59/59
# ----------
# train Loss: 0.3665 Acc: 0.8966
# val Loss: 0.9900 Acc: 0.7401
#
# Training complete in 14m 28s
# Best val Acc: 0.758028

# %%
feature_extract = False

# %%
feature_extract = False
set_parameter_requires_grad(model_ft, feature_extract)

# %%
model_ft, hist = train_model(model_ft, dataloaders, criterion, optimizer_ft, num_epochs=num_epochs)
# Out:
# Epoch 0/59
# ----------
# train Loss: 0.4200 Acc: 0.8901
# val Loss: 1.0219 Acc: 0.7371
#
# Epoch 1/59
# ----------
#
# Epoch 26/59
# ----------
# train Loss: 0.3304 Acc: 0.9101
# val Loss: 1.0218 Acc: 0.7371
#
# Epoch 27/59
# ----------
# train Loss: 0.3291 Acc: 0.9142
# val Loss: 1.0528 Acc: 0.7386
#
# Epoch 28/59
# ----------
# train Loss: 0.3153 Acc: 0.9164
# val Loss: 1.0571 Acc: 0.7326
#
# Epoch 29/59
# ----------
# train Loss: 0.3197 Acc: 0.9130
# val Loss: 1.0534 Acc: 0.7409
#
# Epoch 30/59
# ----------
# train Loss: 0.3133 Acc: 0.9164
# val Loss: 1.0494 Acc: 0.7311
#
# Epoch 31/59
# ----------
# train Loss: 0.3073 Acc: 0.9157
# val Loss: 1.0255 Acc: 0.7409
#
# Epoch 32/59
# ----------
# train Loss: 0.2981 Acc: 0.9205
# val Loss: 1.0311 Acc: 0.7364
#
# Epoch 33/59
# ----------
# train Loss: 0.2923 Acc: 0.9185
# val Loss: 1.0369 Acc: 0.7394
#
# Epoch 34/59
# ----------
# train Loss: 0.3135 Acc: 0.9171
# val Loss: 1.0438 Acc: 0.7409
#
# Epoch 35/59
# ----------
# train Loss: 0.2843 Acc: 0.9257
# val Loss: 1.0280 Acc: 0.7356
#
# Epoch 36/59
# ----------
# train Loss: 0.3015 Acc: 0.9185
# val Loss: 1.0500 Acc: 0.7311
#
# Epoch 37/59
# ----------
# train Loss: 0.2646 Acc: 0.9274
# val Loss: 1.0495 Acc: 0.7349
#
# Epoch 38/59
# ----------
# train Loss: 0.2823 Acc: 0.9222
# val Loss: 1.0389 Acc: 0.7296
#
# Epoch 39/59
# ----------
# train Loss: 0.3037 Acc: 0.9207
# val Loss: 1.0749 Acc: 0.7349
#
# Epoch 40/59
# ----------
# train Loss: 0.2899 Acc: 0.9216
# val Loss: 1.0430 Acc: 0.7341
#
# Epoch 41/59
# ----------
# train Loss: 0.3007 Acc: 0.9188
# val Loss: 1.0722 Acc: 0.7259
#
# Epoch 42/59
# ----------
# train Loss: 0.3020 Acc: 0.9222
# val Loss: 1.0681 Acc: 0.7401
#
# Epoch 43/59
# ----------
# train Loss: 0.2595 Acc: 0.9280
# val Loss: 1.0855 Acc: 0.7252
#
# Epoch 44/59
# ----------
# train Loss: 0.2889 Acc: 0.9229
# val Loss: 1.0844 Acc: 0.7222
#
# Epoch 45/59
# ----------
# train Loss: 0.2646 Acc: 0.9308
# val Loss: 1.0999 Acc: 0.7237
#
# Epoch 46/59
# ----------
# train Loss: 0.2989 Acc: 0.9209
# val Loss: 1.1068 Acc: 0.7267
#
# Epoch 47/59
# ----------
# train Loss: 0.2767 Acc: 0.9269
# val Loss: 1.1219 Acc: 0.7207
#
# Epoch 48/59
# ----------
# train Loss: 0.2621 Acc: 0.9302
# val Loss: 1.1168 Acc: 0.7177
#
# Epoch 49/59
# ----------
# train Loss: 0.2514 Acc: 0.9334
# val Loss: 1.0935 Acc: 0.7222
#
# Epoch 50/59
# ----------
# train Loss: 0.2607 Acc: 0.9298
# val Loss: 1.0903 Acc: 0.7319
#
# Epoch 51/59
# ----------
# train Loss: 0.2485 Acc: 0.9321
# val Loss: 1.1108 Acc: 0.7267
#
# Epoch 52/59
# ----------
# train Loss: 0.2783 Acc: 0.9274
# val Loss: 1.1404 Acc: 0.7177
#
# Epoch 53/59
# ----------
# train Loss: 0.2541 Acc: 0.9310
# val Loss: 1.0832 Acc: 0.7379
#
# Epoch 54/59
# ----------
# train Loss: 0.2483 Acc: 0.9313
# val Loss: 1.1111 Acc: 0.7334
#
# Epoch 55/59
# ----------
# train Loss: 0.2596 Acc: 0.9291
# val Loss: 1.1594 Acc: 0.7170
#
# Epoch 56/59
# ----------
# train Loss: 0.2598 Acc: 0.9270
# val Loss: 1.0975 Acc: 0.7311
#
# Epoch 57/59
# ----------
# train Loss: 0.2498 Acc: 0.9352
# val Loss: 1.1011 Acc: 0.7237
#
# Epoch 58/59
# ----------
# train Loss: 0.2678 Acc: 0.9325
# val Loss: 1.1414 Acc: 0.7199
#
# Epoch 59/59
# ----------
# train Loss: 0.2435 Acc: 0.9356
# val Loss: 1.0970 Acc: 0.7326
#
# Training complete in 14m 29s
# Best val Acc: 0.747573

# %%
model_ft = models.resnet50(pretrained=True)
set_parameter_requires_grad(model_ft, feature_extract)
num_ftrs = model_ft.fc.in_features

# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, 67)

model_ft = model_ft.to(device)


criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 9 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=9, gamma=0.1)

# %%
model_ft, hist = train_model(model_ft, dataloaders, criterion, optimizer_ft, num_epochs=num_epochs)
# Out:
# Epoch 0/59
# ----------
# train Loss: 3.7466 Acc: 0.1799
# val Loss: 2.6502 Acc: 0.4511
#
# Epoch 1/59
# ----------
# train Loss: 2.4643 Acc: 0.4600
# val Loss: 1.6434 Acc: 0.6042
#
# Epoch 2/59
# ----------
# train Loss: 1.7965 Acc: 0.5686
# val Loss: 1.2607 Acc: 0.6677
#
# Epoch 3/59
# ----------
# train Loss: 1.4758 Acc: 0.6249
# val Loss: 1.0946 Acc: 0.6945
#
# Epoch 4/59
# ----------
# train Loss: 1.2965 Acc: 0.6647
# val Loss: 0.9963 Acc: 0.7184
#
# Epoch 5/59
# ----------
# train Loss: 1.1539 Acc: 0.6955
# val Loss: 0.9239 Acc: 0.7319
#
# Epoch 6/59
# ----------
# train Loss: 1.0460 Acc: 0.7164
# val Loss: 0.8757 Acc: 0.7431
#
# Epoch 7/59
# ----------
# train Loss: 0.9890 Acc: 0.7347
# val Loss: 0.8534 Acc: 0.7647
#
# Epoch 8/59
# ----------
# train Loss: 0.9043 Acc: 0.7552
# val Loss: 0.8141 Acc: 0.7677
#
# Epoch 9/59
# ----------
# train Loss: 0.8489 Acc: 0.7632
# val Loss: 0.8298 Acc: 0.7730
#
# Epoch 10/59
# ----------
# train Loss: 0.7983 Acc: 0.7800
# val Loss: 0.8207 Acc: 0.7610
#
# Epoch 11/59
# ----------
# train Loss: 0.7233 Acc: 0.8097
# val Loss: 0.7884 Acc: 0.7647
#
# Epoch 12/59
# ----------
# train Loss: 0.6872 Acc: 0.8143
# val Loss: 0.7877 Acc: 0.7737
#
# Epoch 13/59
# ----------
# train Loss: 0.6714 Acc: 0.8188
# val Loss: 0.7934 Acc: 0.7640
#
# Epoch 14/59
# ----------
# train Loss: 0.6254 Acc: 0.8302
# val Loss: 0.8125 Acc: 0.7618
#
# Epoch 15/59
# ----------
# train Loss: 0.6152 Acc: 0.8352
# val Loss: 0.8103 Acc: 0.7603
#
# Epoch 16/59
# ----------
# train Loss: 0.5767 Acc: 0.8470
# val Loss: 0.7839 Acc: 0.7730
#
# Epoch 17/59
# ----------
# train Loss: 0.5588 Acc: 0.8507
# val Loss: 0.7809 Acc: 0.7782
#
# Epoch 18/59
# ----------
# train Loss: 0.5367 Acc: 0.8567
# val Loss: 0.7693 Acc: 0.7916
#
# Epoch 19/59
# ----------
# train Loss: 0.5220 Acc: 0.8599
# val Loss: 0.7758 Acc: 0.7857
#
# Epoch 20/59
# ----------
# train Loss: 0.4841 Acc: 0.8662
# val Loss: 0.8189 Acc: 0.7745
#
# Epoch 21/59
# ----------
# train Loss: 0.4690 Acc: 0.8770
# val Loss: 0.8109 Acc: 0.7685
#
# Epoch 22/59
# ----------
# train Loss: 0.4616 Acc: 0.8737
# val Loss: 0.7995 Acc: 0.7767
#
# Epoch 23/59
# ----------
# train Loss: 0.4336 Acc: 0.8819
# val Loss: 0.8448 Acc: 0.7730
#
# Epoch 24/59
# ----------
# train Loss: 0.4422 Acc: 0.8813
# val Loss: 0.8338 Acc: 0.7655
#
# Epoch 25/59
# ----------
# train Loss: 0.4091 Acc: 0.8864
# val Loss: 0.8028 Acc: 0.7752
#
# Epoch 26/59
# ----------
# train Loss: 0.4074 Acc: 0.8959
# val Loss: 0.8071 Acc: 0.7737
#
# Epoch 27/59
# ----------
# train Loss: 0.3855 Acc: 0.8968
# val Loss: 0.8127 Acc: 0.7789
#
# Epoch 28/59
# ----------
# train Loss: 0.3894 Acc: 0.9000
# val Loss: 0.8159 Acc: 0.7722
#
# Epoch 29/59
# ----------
# train Loss: 0.3916 Acc: 0.8955
# val Loss: 0.8355 Acc: 0.7715
#
# Epoch 30/59
# ----------
# train Loss: 0.3753 Acc: 0.8994
# val Loss: 0.8467 Acc: 0.7685
#
# Epoch 31/59
# ----------
# train Loss: 0.3582 Acc: 0.9060
# val Loss: 0.8430 Acc: 0.7662
#
# Epoch 32/59
# ----------
# train Loss: 0.3532 Acc: 0.9056
# val Loss: 0.8314 Acc: 0.7819
#
# Epoch 33/59
# ----------
# train Loss: 0.3498 Acc: 0.9037
# val Loss: 0.8632 Acc: 0.7707
#
# Epoch 34/59
# ----------
# train Loss: 0.3234 Acc: 0.9117
# val Loss: 0.8175 Acc: 0.7789
#
# Epoch 35/59
# ----------
# train Loss: 0.3182 Acc: 0.9168
# val Loss: 0.8375 Acc: 0.7782
#
# Epoch 36/59
# ----------
# train Loss: 0.3149 Acc: 0.9157
# val Loss: 0.9173 Acc: 0.7573
#
# Epoch 37/59
# ----------
# train Loss: 0.3054 Acc: 0.9216
# val Loss: 0.8969 Acc: 0.7595
#
# Epoch 38/59
# ----------
# train Loss: 0.3244 Acc: 0.9147
# val Loss: 0.8851 Acc: 0.7685
#
# Epoch 39/59
# ----------
# train Loss: 0.3167 Acc: 0.9140
# val Loss: 0.9103 Acc: 0.7528
#
# Epoch 40/59
# ----------
# train Loss: 0.2992 Acc: 0.9224
# val Loss: 0.8843 Acc: 0.7677
#
# Epoch 41/59
# ----------
# train Loss: 0.2944 Acc: 0.9244
# val Loss: 0.8800 Acc: 0.7633
#
# Epoch 42/59
# ----------
# train Loss: 0.2985 Acc: 0.9250
# val Loss: 0.9277 Acc: 0.7513
#
# Epoch 43/59
# ----------
# train Loss: 0.2770 Acc: 0.9270
# val Loss: 0.8793 Acc: 0.7745
#
# Epoch 44/59
# ----------
# train Loss: 0.2960 Acc: 0.9177
# val Loss: 0.8910 Acc: 0.7655
#
# Epoch 45/59
# ----------
# train Loss: 0.2844 Acc: 0.9267
# val Loss: 0.9267 Acc: 0.7685
#
# Epoch 46/59
# ----------
# train Loss: 0.2586 Acc: 0.9315
# val Loss: 0.9238 Acc: 0.7677
#
# Epoch 47/59
# ----------
# train Loss: 0.2623 Acc: 0.9313
# val Loss: 0.9003 Acc: 0.7715
#
# Epoch 48/59
# ----------
# train Loss: 0.2739 Acc: 0.9289
# val Loss: 0.9459 Acc: 0.7595
#
# Epoch 49/59
# ----------
# train Loss: 0.2409 Acc: 0.9388
# val Loss: 0.9353 Acc: 0.7595
#
# Epoch 50/59
# ----------
# train Loss: 0.2548 Acc: 0.9345
# val Loss: 0.9074 Acc: 0.7677
#
# Epoch 51/59
# ----------
# train Loss: 0.2612 Acc: 0.9274
# val Loss: 0.9215 Acc: 0.7737
#
# Epoch 52/59
# ----------
# train Loss: 0.2624 Acc: 0.9257
# val Loss: 0.9139 Acc: 0.7692
#
# Epoch 53/59
# ----------
# train Loss: 0.2684 Acc: 0.9261
# val Loss: 0.9540 Acc: 0.7573
#
# Epoch 54/59
# ----------
# train Loss: 0.2554 Acc: 0.9300
# val Loss: 0.9428 Acc: 0.7633
#
# Epoch 55/59
# ----------
# train Loss: 0.2522 Acc: 0.9328
# val Loss: 0.9188 Acc: 0.7565
#
# Epoch 56/59
# ----------
# train Loss: 0.2442 Acc: 0.9371
# val Loss: 0.9282 Acc: 0.7618
#
# Epoch 57/59
# ----------
# train Loss: 0.2400 Acc: 0.9343
# val Loss: 0.9355 Acc: 0.7633
#
# Epoch 58/59
# ----------
# train Loss: 0.2352 Acc: 0.9356
# val Loss: 0.9057 Acc: 0.7580
#
# Epoch 59/59
# ----------
# train Loss: 0.2502 Acc: 0.9375
# val Loss: 0.9415 Acc: 0.7521
#
# Training complete in 35m 12s
# Best val Acc: 0.791636

# %%
torch.save(model_ft.state_dict(), './model/bst_resnet50.pt')
